# %%
from decouple import config

# %%
assert config("ALPHA_VANTAGE_API_KEY", default=None, cast=str) is not None

# %%
ALPHA_VANTAGE_API_KEY=config("ALPHA_VANTAGE_API_KEY", default=None, cast=str)

# %%
import requests

# Replace "ALPHA_VANTAGE_API_KEY" with your actual API key
api_key = ALPHA_VANTAGE_API_KEY

# Define the function you want to use
#function = "TIME_SERIES_DAILY"

params = {
    "api_key": api_key,
    "ticker": "AAPL",
    "function" : "TIME_SERIES_DAILY"
    
}

# Use the defined function variable in the URL
url = f'https://www.alphavantage.co/query?function={function}&symbol={params["ticker"]}&interval=5min&apikey={api_key}'.format(**params)
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'AAPL', '3. Last Refreshed': '2024-11-22', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2024-11-22': {'1. open': '228.0600', '2. high': '230.7199', '3. low': '228.0600', '4. close': '229.8700', '5. volume': '38168252'}, '2024-11-21': {'1. open': '228.8800', '2. high': '230.1550', '3. low': '225.7103', '4. close': '228.5200', '5. volume': '42108327'}, '2024-11-20': {'1. open': '228.0600', '2. high': '229.9300', '3. low': '225.8900', '4. close': '229.0000', '5. volume': '35169566'}, '2024-11-19': {'1. open': '226.9800', '2. high': '230.1600', '3. low': '226.6600', '4. close': '228.2800', '5. volume': '36211774'}, '2024-11-18': {'1. open': '225.2500', '2. high': '229.7400', '3. low': '225.1700', '4. close': '228.0200', '5. volume': '44686020'}, '2024-11-15': {'1. open': '226.4000', '2. high': '226.9200', '3. low': '224.2700', '4. close': '225.0000', 
# ...

# %%
data
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2024-11-22 19:55:00',
#   '4. Interval': '5min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (5min)': {'2024-11-22 19:55:00': {'1. open': '223.3000',
#    '2. high': '223.3200',
#    '3. low': '223.3000',
#    '4. close': '223.3200',
#    '5. volume': '17'},
#   '2024-11-22 19:50:00': {'1. open': '223.3000',
#    '2. high': '223.3000',
#    '3. low': '223.3000',
#    '4. close': '223.3000',
#    '5. volume': '5'},
#   '2024-11-22 19:45:00': {'1. open': '223.1500',
#    '2. high': '223.3000',
#    '3. low': '223.1500',
#    '4. close': '223.3000',
#    '5. volume': '21'},
#   '2024-11-22 19:40:00': {'1. open': '223.3000',
#    '2. high': '223.3000',
#    '3. low': '223.3000',
#    '4. close': '223.3000',
#    '5. volume': '4'},
#   '2024-11-22 19:35:00': {'1. open': '223.3000',
# ...
